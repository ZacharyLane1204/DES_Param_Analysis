# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/home/users/zgl12/DES_Param_Analysis/run_publication_registry.csv')

df.columns

# %%
df.sort_values(by=['Name of column']).head(10) # Chi2

# %%
df.sort_values(by=['Name of column']).head(10) # Chi2/d.o.f.

# %%
df.sort_values(by=['Name of column']).head(10) # log Z

# %%
df.sort_values(by=['Name of column']).head(10) # log Z
