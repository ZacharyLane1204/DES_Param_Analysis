# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib widget

# %%
df = pd.read_csv("/Users/zgl12/Modules/DES_Param_Analysis/run_publication_registry.csv")

baseline_val = df[df['run_name'] == 'baseline']["logZ"].values[0]

# %%
df
# Out:
#                                               run_name            timestamp  \
# 0                                nuisance/noalphagamma  2026-08-27T00:52:22
# 1                                 nuisance/noalphabeta  2026-08-27T01:09:26
# 2                                 nuisance/nobetagamma  2026-08-27T01:13:55
# 3                                     nuisance/noalpha  2026-08-27T01:23:08
# 4                                     nuisance/nogamma  2026-08-27T01:28:01
# ..                                                 ...                  ...
# 481  ssfr/ssfr_sigmoid_F0ftau_hcol_quadratic_mass_s...  2026-09-02T01:17:06
# 482  ssfr/ssfr_tanh_F0ftau_hcol_tanh_mass_sigmoid_M...  2026-09-02T01:44:21
# 483  ssfr/ssfr_tanh_F0ftau_hcol_quadratic_mass_sigm...  2026-09-02T02:05:46
# 484  ssfr/ssfr_sigmoid_F0ftau_hcol_asymm_mass_sigmo...  2026-09-02T03:16:15
# 485  ssfr/ssfr_tanh_F0ftau_hcol_asymm_mass_sigmoid_...  2026-09-02T04:35:35
#
# ...

# %%
def section_df(df, substring):
    temp_df = df[df['run_name'].str.contains(substring)]
    return temp_df[temp_df['logZ'] >= (baseline_val+1)]

# %%
# df.sort_values(by=["chi2_dof"], ascending=True).head(20)

# %%
# df.sort_values(by=["chi2"], ascending=True).head(20)

# %%
section_df(df, 'stretch/').sort_values(by=["logZ"], ascending=False).head(20)
# Out:
# Empty DataFrame
# ...

# %%
section_df(df, 'evolution/').sort_values(by=["logZ"], ascending=False).head(20)
# Out:
# Empty DataFrame
# ...

# %%
section_df(df, 'sncolour/').sort_values(by=["logZ"], ascending=False).head(20)
# Out:
#                                          run_name            timestamp  nlive  \
# 26             sncolour/sncolour_softbroken_sntau  2026-08-27T03:32:35   3000
# 40                 sncolour/sncolour_quadratic_c0  2026-08-27T03:44:33   3000
# 118            sncolour/sncolour_stepbroken_sntau  2026-08-27T10:38:35   3000
# 44                      sncolour/sncolour_tanh_c0  2026-08-27T03:48:03   3000
# 67           sncolour/sncolour_softbroken_c0sntau  2026-08-27T05:05:33   3500
# 138  sncolour/sncolour_asymm_gauss_weight_c0sntau  2026-08-27T11:58:47   3500
#
#      ndim  N_sne   dof     logZ  logZ_err      chi2  chi2_dof  ...  tau_mean  \
# 26      6   1820  1814 -449.234     0.064  1682.132    0.9273  ...       NaN
# 40      6   1820  1814 -450.291     0.067  1682.198    0.9273  ...       NaN
# 118     6   1820  1814 -450.758     0.069  1681.671    0.9271  ...       NaN
# 44      6   1820  1814 -450.863     0.068  1682.251    0.9274  ...       NaN
# ...

# %%
section_df(df, 'host_col/').sort_values(by=["logZ"], ascending=False).head(20)
# Out:
#                                               run_name            timestamp  \
# 95      host_col/ssfr_none_hcol_sigmoid_C0_mass_linear  2026-08-27T09:48:46
# 97   host_col/ssfr_none_hcol_sigmoid_C0_mass_double...  2026-08-27T10:01:37
# 109   host_col/ssfr_none_hcol_quadratic_C0_mass_linear  2026-08-27T10:27:06
# 115        host_col/ssfr_none_hcol_tanh_C0_mass_linear  2026-08-27T10:35:46
# 120   host_col/ssfr_none_hcol_tanh_C0_mass_double_step  2026-08-27T10:44:47
# 117  host_col/ssfr_none_hcol_quadratic_C0_mass_doub...  2026-08-27T10:37:10
# 141  host_col/ssfr_none_hcol_sigmoid_C0_mass_sigmoi...  2026-08-27T12:10:45
# 122  host_col/ssfr_none_hcol_linear_mass_sigmoid_M0tau  2026-08-27T10:48:29
# 125   host_col/ssfr_none_hcol_asymm_C0htau_mass_linear  2026-08-27T11:14:32
# 127  host_col/ssfr_none_hcol_asymm_C0htau_mass_doub...  2026-08-27T11:19:02
# 128     host_col/ssfr_none_hcol_linear_mass_tanh_M0tau  2026-08-27T11:23:15
# ...

# %%
section_df(df, 'mass/').sort_values(by=["logZ"], ascending=False).head(20)
# Out:
#                        run_name            timestamp  nlive  ndim  N_sne  \
# 181     mass/mass_sigmoid_M0tau  2026-08-27T20:19:23   3000     6   1820
# 169            mass/mass_linear  2026-08-27T15:33:44   2000     4   1820
# 183        mass/mass_tanh_M0tau  2026-08-27T21:04:54   3000     6   1820
# 168       mass/mass_double_step  2026-08-27T15:32:37   2000     4   1820
# 184  mass/mass_double_step_M0M1  2026-08-27T21:50:15   3000     6   1820
# 175        mass/mass_sigmoid_M0  2026-08-27T19:09:41   2500     5   1820
# 170           mass/mass_sigmoid  2026-08-27T15:37:05   2000     4   1820
# 185     mass/mass_spline_k1k2k3  2026-08-27T21:39:09   3500     7   1820
# 176           mass/mass_tanh_M0  2026-08-27T19:13:25   2500     5   1820
#
#       dof     logZ  logZ_err      chi2  chi2_dof  ...  tau_mean  tau_std  \
# 181  1814 -446.952     0.048  1690.310    0.9318  ...   1.01849  0.44706
# 169  1816 -447.335     0.056  1693.918    0.9328  ...       NaN      NaN
# ...

# %%
section_df(df, 'interaction/').sort_values(by=["logZ"], ascending=False).head(20)
# Out:
#                                run_name            timestamp  nlive  ndim  \
# 114  interaction/interaction_gammaalpha  2026-08-27T10:31:14   3000     6
#
#      N_sne   dof     logZ  logZ_err     chi2  chi2_dof  ...  tau_mean  \
# 114   1820  1814 -450.762     0.068  1682.71    0.9276  ...       NaN
#
#      tau_std  M1_mean  M1_std xi_sSFR_mass_mean xi_sSFR_mass_std  \
# 114      NaN      NaN     NaN               NaN              NaN
#
#     xi_sSFR_col_mean xi_sSFR_col_std omega_mean omega_std
# 114              NaN             NaN        NaN       NaN
#
# [1 rows x 99 columns]

# %%
section_df(df, 'ssfr/').sort_values(by=["logZ"], ascending=False).head(20)
# Out:
#                                               run_name            timestamp  \
# 412               ssfr/ssfr_tanh_hcol_none_mass_linear  2026-09-01T13:16:48
# 440               ssfr/ssfr_tanh_hcol_tanh_mass_linear  2026-09-01T16:53:04
# 452  ssfr/ssfr_tanh_F0ftau_hcol_none_mass_sigmoid_M...  2026-09-01T18:18:35
# 429            ssfr/ssfr_tanh_hcol_sigmoid_mass_linear  2026-09-01T16:05:44
# 333        ssfr/ssfr_tanh_F0ftau_hcol_none_mass_linear  2026-08-29T17:14:46
# 388        ssfr/ssfr_tanh_F0ftau_hcol_tanh_mass_linear  2026-08-29T22:59:28
# 482  ssfr/ssfr_tanh_F0ftau_hcol_tanh_mass_sigmoid_M...  2026-09-02T01:44:21
# 360     ssfr/ssfr_tanh_F0ftau_hcol_sigmoid_mass_linear  2026-08-29T21:19:16
# 456              ssfr/ssfr_tanh_hcol_asymm_mass_linear  2026-09-01T18:34:47
# 444     ssfr/ssfr_step_F0_hcol_none_mass_sigmoid_M0tau  2026-09-01T17:08:17
# 476  ssfr/ssfr_tanh_F0ftau_hcol_sigmoid_mass_sigmoi...  2026-09-01T23:02:48
# ...
